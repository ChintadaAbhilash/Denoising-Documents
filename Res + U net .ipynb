# %%
import torch 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 

import torchvision 
import torch.nn.functional as F 

from torch import nn , optim
from torchvision import datasets , transforms , models 
from torch.utils import data 

from collections import OrderedDict
from PIL import Image 

import time 
import pickle 

import tqdm

from torch.utils.data import DataLoader

# %%
class Conv(nn.Module):
    def __init__(self , in_channels , out_channels , batch_norm = True):
        super(Conv , self).__init__()
        self.conv = nn.Conv2d(in_channels , out_channels , kernel_size = 3 , padding = 1 , stride = 1)
        self.norm = batch_norm 
        self.batch_norm = nn.BatchNorm2d(out_channels)
        
    def forward(self , x):
        
        if self.norm :
            x = self.batch_norm(self.conv(x))
            
        else :
            x = self.conv(x)
            
        return x

# %%
class Resblock(nn.Module):
    def __init__(self , in_channels , out_channels):
        super(Resblock , self).__init__()
        self.conv1 = Conv(in_channels , out_channels , batch_norm = True)
        self.conv2 = Conv(in_channels , out_channels , batch_norm = True)
        self.relu = nn.LeakyReLU(negative_slope = 0.2)
        
    def forward(self , x):
        x = self.relu(self.conv1(x))
        x = x + self.conv2(x)
        
        return x

# %%
class Outconv(nn.Module):
    def __init__(self , input_ch , output_ch):
        super(Outconv , self).__init__()
        self.conv = nn.ConvTranspose2d(input_ch , output_ch , kernel_size = 4 , stride = 2 , padding = 1)
        
    def forward(self , x):
        x = torch.sigmoid(self.conv(x))
        
        return x

# %%
class Downsample(nn.Module):
    def __init__(self , input_ch , output_ch , batch_norm = True):
        super(Downsample , self).__init__()
        self.conv = nn.Conv2d( input_ch , output_ch , kernel_size = 4 , padding = 1 , stride = 2) 
        self.norm = nn.BatchNorm2d(output_ch)
        self.leaky_relu = nn.LeakyReLU(negative_slope = 0.2)
        self.batch_norm = batch_norm
        self.resblock = Resblock(output_ch , output_ch)
        
    def forward(self , x):
        if self.batch_norm:
            x = self.leaky_relu(self.norm(self.conv(x)))
            
        else :
            x = self.leaky_relu(self.conv(x))
            
        x = self.resblock(x)
        
        return x

# %%
class Upsample(nn.Module):
    def __init__(self , input_ch , output_ch , dropout = False):
        super(Upsample , self).__init__()
        self.deconv = nn.ConvTranspose2d(input_ch , output_ch , kernel_size = 4 , stride = 2 , padding = 1)
        self.norm = nn.BatchNorm2d(output_ch)
        self.leaky_relu = nn.LeakyReLU(negative_slope = 0.2)
        self.drop = dropout
        self.dropout = nn.Dropout2d(0.3)
        self.resblock = Resblock(output_ch , output_ch)
        
    def forward(self , x):
        if self.drop :
            x = self.leaky_relu(self.dropout(self.norm(self.deconv(x))))
            
        else :
            x = self.leaky_relu(self.norm(self.deconv(x)))
            
        x = self.resblock(x)
        
        return x

# %%
class Unet(nn.Module):
    def __init__(self , in_channels , out_channels):
        super(Unet , self).__init__()
        
        # Input 256 * 256
        
        self.in_conv = Downsample(in_channels , 32 , batch_norm = False)  # 32 * 128 * 128
        self.down1 = Downsample(32 , 64)  # 64 * 64 * 64
        self.down2 = Downsample(64 , 128) # 128 * 32 * 32 
        self.down3 = Downsample(128 , 256) # 256 * 16 * 16
        self.down4 = Downsample(256 , 512) # 512 * 8 * 8
        self.down5 = Downsample(512 , 512) # 512 * 4 * 4
        self.down6 = Downsample(512 , 512) # 512 * 2 * 2 
        self.down7 = Downsample(512 , 512) # 512 * 1 * 1
        
        self.up_1 = Upsample(512 , 512 , dropout = True) # 512 * 2 * 2
        self.up_2 = Upsample(1024 , 512 , dropout = True) # 512 * 4 * 4 
        self.up1 = Upsample(1024 , 512 , dropout = True) # 512 * 8 * 8
        self.up2 = Upsample(1024 , 256 , dropout = True) # 256 * 16 * 16
        self.up3 = Upsample(512 , 128)  # 128 * 32 * 32 
        self.up4 = Upsample(256 , 64)  # 64 * 64 * 64
        self.up5 = Upsample(128 , 32)  # 32 * 128 * 128
        self.out_conv = Outconv(64 , out_channels) # out_channels * 256 * 256
        
        self.down_stack = [self.in_conv , self.down1 , self.down2 , 
                           self.down3 , self.down4 , self.down5 , 
                           self.down6 , self.down7]
        
        self.up_stack = [self.up_1 , self.up_2 , self.up1 ,
                         self.up2 ,self.up3 , self.up4 ,
                         self.up5]
        
        
    def forward(self , x):
        skips = []
        
        for down in self.down_stack:
            x = down(x)
            #print(x.shape)
            skips.append(x)
            
        skips = list(reversed(skips[:-1]))
        
        for up , skip in zip(self.up_stack , skips):
            x = up(x)
           # print(x.shape , skip.shape)
            x = torch.cat([x, skip], dim=1)
            
        x = self.out_conv(x)
        
        return x

# %%
model = Unet(1,1)

device  = "cuda"

model.to(device)
# Out:
# Unet(
#   (in_conv): Downsample(
#     (conv): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down1): Downsample(
#     (conv): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down2): Downsample(
#     (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down3): Downsample(
#     (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down4): Downsample(
#     (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down5): Downsample(
#     (conv): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down6): Downsample(
#     (conv): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (down7): Downsample(
#     (conv): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up_1): Upsample(
#     (deconv): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up_2): Upsample(
#     (deconv): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up1): Upsample(
#     (deconv): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up2): Upsample(
#     (deconv): ConvTranspose2d(1024, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up3): Upsample(
#     (deconv): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up4): Upsample(
#     (deconv): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (up5): Upsample(
#     (deconv): ConvTranspose2d(128, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leaky_relu): LeakyReLU(negative_slope=0.2)
#     (dropout): Dropout2d(p=0.3)
#     (resblock): Resblock(
#       (conv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv2): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (out_conv): Outconv(
#     (conv): ConvTranspose2d(64, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %%
import glob

img_noisy_names = []

for i in glob.glob("train/*.png"):
    img_noisy_names.append(i)
    
print(len(img_noisy_names))
# Out:
# 144

# %%
img_names = []

for i in glob.glob("train_cleaned/*.png"):
    img_names.append(i)
    
print(len(img_names))
# Out:
# 144

# %%
from sklearn.model_selection import train_test_split 

Xtrain , Xtest , Ytrain , Ytest  = train_test_split(img_noisy_names , img_names , test_size = 0.2 , random_state = 2)

# %%
print(len(Xtrain))
print(len(Xtest))
print(len(Ytrain))
print(len(Ytest))
# Out:
# 115
# 29
# 115
# 29

# %%
class Dataset(data.Dataset):
    def __init__(self, img_noisy_names , img_names , transform=None):
        self.noisy = img_noisy_names
        self.img = img_names
        self.transform = transform

    def __len__(self):
        return len(self.noisy)

    def __getitem__(self, index):
        X = Image.open(self.noisy[index])
        Y = Image.open(self.img[index])
        
        if self.transform:
            X = self.transform(X)
            Y = self.transform(Y)

        return X , Y

# %%
data_transforms = {
    
    'train' : transforms.Compose([transforms.Resize((256,256)),
                                 transforms.ToTensor(),
                                 ]),
    
    'test' : transforms.Compose([transforms.Resize((256,256)),
                                 transforms.ToTensor(),
                                ])
}

# %%
training_data = Dataset( Xtrain , Ytrain , transform = data_transforms['train'])
testing_data = Dataset( Xtest , Ytest  ,transform = data_transforms['test'])

# %%
data_loader = {
    
    'train' : DataLoader(training_data, batch_size = 8 , shuffle = True) , 
    
    'test' : DataLoader( testing_data , batch_size = 8 , shuffle = False)
    
}

# %%
images , labels = next(iter(data_loader['train']))

images = images.numpy()

print(images.shape)

images = images.transpose(0,2,3,1)

print(images.shape)

img = images[0]

print(img.shape)

img = img.clip(0,1)

plt.imshow(img.reshape(256,256) , cmap = "gray")
# Out:
# (8, 1, 256, 256)
# (8, 256, 256, 1)
# (256, 256, 1)

# %%
# specify loss function
criterion = nn.MSELoss()

# specify loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
n_epochs = 50
    
best_test_loss = np.Inf

for epoch in range(1, n_epochs+1):
    
    train_loss = 0.0
    test_loss = 0.0
    
    model.train()
    for data in data_loader['train']:

        noisy_imgs, images = data
        
        images = images.cuda()
        noisy_imgs = noisy_imgs.cuda()

        optimizer.zero_grad()

        outputs = model(noisy_imgs)

        loss = criterion(outputs, images)

        loss.backward()

        optimizer.step()

        train_loss += loss.item()*images.size(0)
        
    with torch.no_grad():
        
        model.eval()
        
        for data in data_loader['test']:
            noisy_imgs, images = data
        
            images = images.cuda()
            noisy_imgs = noisy_imgs.cuda()

            outputs = model(noisy_imgs)

            loss = criterion(outputs, images)

            test_loss += loss.item()*images.size(0)
        
    test_loss = test_loss/len(data_loader['test'])
    train_loss = train_loss/len(data_loader['train'])
    
    if test_loss < best_test_loss :
        print(" Saving model with test loss {:.4f} < {:.4f}".format(test_loss , best_test_loss))
        best_test_loss = test_loss
        torch.save(model.state_dict() , "CustomUnetweights.pth")
    
    print('Epoch: {} \tTraining Loss: {:.4f} \t Testing Loss : {:.4f}'.format( epoch, train_loss , test_loss))
# Out:
#  Saving model with test loss 0.9100 < inf
# Epoch: 1 	Training Loss: 0.9295 	 Testing Loss : 0.9100
#  Saving model with test loss 0.3279 < 0.9100
# Epoch: 2 	Training Loss: 0.2909 	 Testing Loss : 0.3279
#  Saving model with test loss 0.1229 < 0.3279
# Epoch: 3 	Training Loss: 0.0916 	 Testing Loss : 0.1229
#  Saving model with test loss 0.0464 < 0.1229
# Epoch: 4 	Training Loss: 0.0486 	 Testing Loss : 0.0464
#  Saving model with test loss 0.0297 < 0.0464
# Epoch: 5 	Training Loss: 0.0347 	 Testing Loss : 0.0297
#  Saving model with test loss 0.0243 < 0.0297
# Epoch: 6 	Training Loss: 0.0290 	 Testing Loss : 0.0243
#  Saving model with test loss 0.0201 < 0.0243
# Epoch: 7 	Training Loss: 0.0229 	 Testing Loss : 0.0201
#  Saving model with test loss 0.0185 < 0.0201
# Epoch: 8 	Training Loss: 0.0203 	 Testing Loss : 0.0185
#  Saving model with test loss 0.0176 < 0.0185
# Epoch: 9 	Training Loss: 0.0182 	 Testing Loss : 0.0176
#  Saving model with test loss 0.0159 < 0.0176
# Epoch: 10 	Training Loss: 0.0161 	 Testing Loss : 0.0159
# Epoch: 11 	Training Loss: 0.0159 	 Testing Loss : 0.0171
#  Saving model with test loss 0.0140 < 0.0159
# Epoch: 12 	Training Loss: 0.0162 	 Testing Loss : 0.0140
#  Saving model with test loss 0.0129 < 0.0140
# Epoch: 13 	Training Loss: 0.0155 	 Testing Loss : 0.0129
#  Saving model with test loss 0.0114 < 0.0129
# Epoch: 14 	Training Loss: 0.0131 	 Testing Loss : 0.0114
# Epoch: 15 	Training Loss: 0.0131 	 Testing Loss : 0.0116
# Epoch: 16 	Training Loss: 0.0126 	 Testing Loss : 0.0124
#  Saving model with test loss 0.0108 < 0.0114
# Epoch: 17 	Training Loss: 0.0118 	 Testing Loss : 0.0108
#  Saving model with test loss 0.0096 < 0.0108
# Epoch: 18 	Training Loss: 0.0107 	 Testing Loss : 0.0096
# Epoch: 19 	Training Loss: 0.0110 	 Testing Loss : 0.0104
#  Saving model with test loss 0.0086 < 0.0096
# Epoch: 20 	Training Loss: 0.0107 	 Testing Loss : 0.0086
# Epoch: 21 	Training Loss: 0.0101 	 Testing Loss : 0.0105
#  Saving model with test loss 0.0086 < 0.0086
# Epoch: 22 	Training Loss: 0.0095 	 Testing Loss : 0.0086
#  Saving model with test loss 0.0084 < 0.0086
# Epoch: 23 	Training Loss: 0.0090 	 Testing Loss : 0.0084
# Epoch: 24 	Training Loss: 0.0093 	 Testing Loss : 0.0115
# Epoch: 25 	Training Loss: 0.0102 	 Testing Loss : 0.0092
# Epoch: 26 	Training Loss: 0.0097 	 Testing Loss : 0.0087
#  Saving model with test loss 0.0080 < 0.0084
# Epoch: 27 	Training Loss: 0.0093 	 Testing Loss : 0.0080
# Epoch: 28 	Training Loss: 0.0089 	 Testing Loss : 0.0084
#  Saving model with test loss 0.0072 < 0.0080
# Epoch: 29 	Training Loss: 0.0083 	 Testing Loss : 0.0072
#  Saving model with test loss 0.0071 < 0.0072
# Epoch: 30 	Training Loss: 0.0073 	 Testing Loss : 0.0071
# Epoch: 31 	Training Loss: 0.0084 	 Testing Loss : 0.0143
# Epoch: 32 	Training Loss: 0.0090 	 Testing Loss : 0.0100
# Epoch: 33 	Training Loss: 0.0089 	 Testing Loss : 0.0093
# Epoch: 34 	Training Loss: 0.0078 	 Testing Loss : 0.0078
#  Saving model with test loss 0.0062 < 0.0071
# Epoch: 35 	Training Loss: 0.0069 	 Testing Loss : 0.0062
# Epoch: 36 	Training Loss: 0.0070 	 Testing Loss : 0.0082
# Epoch: 37 	Training Loss: 0.0069 	 Testing Loss : 0.0063
# Epoch: 38 	Training Loss: 0.0073 	 Testing Loss : 0.0156
# Epoch: 39 	Training Loss: 0.0082 	 Testing Loss : 0.0071
#  Saving model with test loss 0.0061 < 0.0062
# Epoch: 40 	Training Loss: 0.0066 	 Testing Loss : 0.0061
#  Saving model with test loss 0.0058 < 0.0061
# Epoch: 41 	Training Loss: 0.0064 	 Testing Loss : 0.0058
# Epoch: 42 	Training Loss: 0.0075 	 Testing Loss : 0.0071
# Epoch: 43 	Training Loss: 0.0062 	 Testing Loss : 0.0060
#  Saving model with test loss 0.0056 < 0.0058
# Epoch: 44 	Training Loss: 0.0059 	 Testing Loss : 0.0056
# Epoch: 45 	Training Loss: 0.0061 	 Testing Loss : 0.0059
# Epoch: 46 	Training Loss: 0.0060 	 Testing Loss : 0.0076
# Epoch: 47 	Training Loss: 0.0068 	 Testing Loss : 0.0061
#  Saving model with test loss 0.0053 < 0.0056
# Epoch: 48 	Training Loss: 0.0062 	 Testing Loss : 0.0053
# Epoch: 49 	Training Loss: 0.0071 	 Testing Loss : 0.0062
# Epoch: 50 	Training Loss: 0.0060 	 Testing Loss : 0.0056

# %%
model.to("cpu")

model.load_state_dict(torch.load("CustomUnetweights.pth"))

from PIL import Image

def load_image(img_path):
    
    image = Image.open(img_path)
        
    in_transform = transforms.Compose([transforms.Resize((256,256)),
                                       transforms.ToTensor(),])
    
    image = in_transform(image)[:1,:,:].unsqueeze(0)
    
    return image

# %%
image = load_image("test/118.png")

with torch.no_grad():
    model.eval()
    output = model(image)
    print(output.shape)
    
output = output.numpy()
    
output = output.transpose(0,2,3,1)

img = output[0]

print(img.shape)

img = img.clip(0,1)

plt.imshow(img.reshape(256,256) , cmap = "gray")
# Out:
# torch.Size([1, 1, 256, 256])
# (256, 256, 1)
